# %%
# !pip install metloom
# Out:
# Collecting metloom
#   Using cached metloom-0.6.1-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting geopandas<1.0.0,>=0.9.0 (from metloom)
#   Using cached geopandas-0.14.4-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: pandas>1.0.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from metloom) (2.2.2)
# Collecting lxml==4.9.3 (from metloom)
#   Using cached lxml-4.9.3-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: requests<3.0.0,>2.0.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from metloom) (2.32.3)
# Requirement already satisfied: beautifulsoup4<5,>4 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from metloom) (4.12.3)
# Collecting zeep>4.0.0 (from metloom)
#   Using cached zeep-4.2.1-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: soupsieve>1.2 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from beautifulsoup4<5,>4->metloom) (2.5)
# Requirement already satisfied: fiona>=1.8.21 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from geopandas<1.0.0,>=0.9.0->metloom) (1.9.6)
# Requirement already satisfied: numpy>=1.22 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from geopandas<1.0.0,>=0.9.0->metloom) (1.26.4)
# Requirement already satisfied: packaging in /srv/conda/envs/notebook/lib/python3.11/site-packages (from geopandas<1.0.0,>=0.9.0->metloom) (24.1)
# Requirement already satisfied: pyproj>=3.3.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from geopandas<1.0.0,>=0.9.0->metloom) (3.6.1)
# Requirement already satisfied: shapely>=1.8.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from geopandas<1.0.0,>=0.9.0->metloom) (2.0.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from pandas>1.0.0->metloom) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from pandas>1.0.0->metloom) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from pandas>1.0.0->metloom) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from requests<3.0.0,>2.0.0->metloom) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from requests<3.0.0,>2.0.0->metloom) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from requests<3.0.0,>2.0.0->metloom) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from requests<3.0.0,>2.0.0->metloom) (2024.7.4)
# Requirement already satisfied: attrs>=17.2.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from zeep>4.0.0->metloom) (23.2.0)
# Collecting isodate>=0.5.4 (from zeep>4.0.0->metloom)
#   Using cached isodate-0.6.1-py2.py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: platformdirs>=1.4.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from zeep>4.0.0->metloom) (4.2.2)
# Collecting requests-toolbelt>=0.7.1 (from zeep>4.0.0->metloom)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting requests-file>=1.5.1 (from zeep>4.0.0->metloom)
#   Using cached requests_file-2.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: click~=8.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas<1.0.0,>=0.9.0->metloom) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas<1.0.0,>=0.9.0->metloom) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas<1.0.0,>=0.9.0->metloom) (0.7.2)
# Requirement already satisfied: six in /srv/conda/envs/notebook/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas<1.0.0,>=0.9.0->metloom) (1.16.0)
# Using cached metloom-0.6.1-py2.py3-none-any.whl (56 kB)
# Using cached lxml-4.9.3-cp311-cp311-manylinux_2_28_x86_64.whl (7.9 MB)
# Using cached geopandas-0.14.4-py3-none-any.whl (1.1 MB)
# Using cached zeep-4.2.1-py3-none-any.whl (101 kB)
# Using cached isodate-0.6.1-py2.py3-none-any.whl (41 kB)
# Using cached requests_file-2.1.0-py2.py3-none-any.whl (4.2 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Installing collected packages: lxml, isodate, requests-toolbelt, requests-file, zeep, geopandas, metloom
#   Attempting uninstall: lxml
#     Found existing installation: lxml 5.3.0
#     Uninstalling lxml-5.3.0:
#       Successfully uninstalled lxml-5.3.0
#   Attempting uninstall: geopandas
#     Found existing installation: geopandas 1.0.1
#     Uninstalling geopandas-1.0.1:
#       Successfully uninstalled geopandas-1.0.1
# Successfully installed geopandas-0.14.4 isodate-0.6.1 lxml-4.9.3 metloom-0.6.1 requests-file-2.1.0 requests-toolbelt-1.0.0 zeep-4.2.1

# %%
import pandas as pd
from metloom.pointdata import CSASMet
from metloom.variables import CSASVariables

station = 'SBSP'  # options are 'SASP', 'SBSP'
#SBSP Senator beck, SASP Swamp angel
site = CSASMet(station)
start_date = pd.to_datetime("2021-04-29")
end_date = pd.to_datetime("2021-04-30")

download_vars = [
    CSASVariables.UP_BROADBAND,
    CSASVariables.UP_NIR_SWIR,
    CSASVariables.DOWN_BROADBAND,
    CSASVariables.DOWN_NIR_SWIR,
    CSASVariables.SNOWDEPTH,
]

df_rad = site.get_hourly_data(start_date, end_date, download_vars)
print(df_rad)
# Out:
#                          UPWARD BROADBAND RADIATION UPWARD NIR/SWIR RADIATION  \
# datetime            site
# 2021-04-29 00:00:00 SBSP
00:00 SBSP       CSAS  POINT Z (-107.72627 37.90688 12186.00000)
# 2021-04-29 01:00:00 SBSP       CSAS  POINT Z (-107.72627 37.90688 12186.00000)
# 2021-04-29 02:00:00 SBSP       CSAS  POINT Z (-107.72627 37.90688 12186.00000)
# 2021-04-29 03:00:00 SBSP       CSAS  POINT Z (-107.72627 37.90688 12186.00000)
# 2021-04-29 04:00:00 SBSP       CSAS  POINT Z (-107.72627 37.90688 12186.00000)
# 2021-04-29 05:00:00 SBSP       CSAS  POINT Z (-107.72627 37.90688 12186.00000)
# 2021-04-29 06:00:00 SBSP       CSAS  POINT Z (-107.72627 37.90688 12186.00000)
# 2021-04-29 07:00:00 SBSP       CSAS  POINT Z (-107.72627 37.90688 12186.00000)
# 2021-04-29 08:00:00 SBSP       CSAS  POINT Z (-107.72627 37.90688 12186.00000)
# 2021-04-29 09:00:00 SBSP       CSAS  POINT Z (-107.72627 37.90688 12186.00000)
# 2021-04-29 10:00:00 SBSP       CSAS  POINT Z (-107.72627 37.90688 12186.00000)
# 2021-04-29 11:00:00 SBSP       CSAS  POINT Z (-107.72627 37.90688 12186.00000)
# 2021-04-29 12:00:00 SBSP       CSAS  POINT Z (-107.72627 37.90688 12186.00000)
# 2021-04-29 13:00:00 SBSP       CSAS  POINT Z (-107.72627 37.90688 12186.00000)
# 2021-04-29 14:00:00 SBSP       CSAS  POINT Z (-107.72627 37.90688 12186.00000)
# 2021-04-29 15:00:00 SBSP       CSAS  POINT Z (-107.72627 37.90688 12186.00000)
# 2021-04-29 16:00:00 SBSP       CSAS  POINT Z (-107.72627 37.90688 12186.00000)
# 2021-04-29 17:00:00 SBSP       CSAS  POINT Z (-107.72627 37.90688 12186.00000)
# 2021-04-29 18:00:00 SBSP       CSAS  POINT Z (-107.72627 37.90688 12186.00000)
# 2021-04-29 19:00:00 SBSP       CSAS  POINT Z (-107.72627 37.90688 12186.00000)
# 2021-04-29 20:00:00 SBSP       CSAS  POINT Z (-107.72627 37.90688 12186.00000)
# 2021-04-29 21:00:00 SBSP       CSAS  POINT Z (-107.72627 37.90688 12186.00000)
# 2021-04-29 22:00:00 SBSP       CSAS  POINT Z (-107.72627 37.90688 12186.00000)
# 2021-04-29 23:00:00 SBSP       CSAS  POINT Z (-107.72627 37.90688 12186.00000)
# 2021-04-30 00:00:00 SBSP       CSAS  POINT Z (-107.72627 37.90688 12186.00000)
# /srv/conda/envs/notebook/lib/python3.11/site-packages/metloom/pointdata/files.py:206: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df[variable.name].loc[df_var.index] = df_var
# /srv/conda/envs/notebook/lib/python3.11/site-packages/metloom/pointdata/files.py:206: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df[variable.name].loc[df_var.index] = df_var
# /srv/conda/envs/notebook/lib/python3.11/site-packages/metloom/pointdata/files.py:206: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df[variable.name].loc[df_var.index] = df_var
# /srv/conda/envs/notebook/lib/python3.11/site-packages/metloom/pointdata/files.py:206: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df[variable.name].loc[df_var.index] = df_var
# /srv/conda/envs/notebook/lib/python3.11/site-packages/metloom/pointdata/files.py:206: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df[variable.name].loc[df_var.index] = df_var

# %%
from metloom.pointdata import CSASMet, SnotelPointData
from metloom.variables import CSASVariables, SnotelVariables
# Get density from red mountain pass which is near by
red_mountain_site = SnotelPointData(
    "713:CO:SNTL", "Red Mountain Pass"
)
# Download depth and SWE at red mountain
df_swe = red_mountain_site.get_daily_data(
    start_date, end_date, variables=[
        SnotelVariables.SWE, SnotelVariables.SNOWDEPTH
    ]
)
# calculate density (kg/m^3) at the site
df_swe["DENSITY"] = 1000.0 * df_swe["SWE"]/df_swe["SNOWDEPTH"]

# %%
df_swe
# Out:
#                                                                         geometry  \
# datetime                  site
# 2021-04-29 08:00:00+00:00 713:CO:SNTL  POINT Z (-107.71389 37.89168 11080.00000)
# 2021-04-30 08:00:00+00:00 713:CO:SNTL  POINT Z (-107.71389 37.89168 11080.00000)
#
#                                         SWE SWE_units  SNOWDEPTH  \
# datetime                  site
# 2021-04-29 08:00:00+00:00 713:CO:SNTL  18.8        in       50.0
# 2021-04-30 08:00:00+00:00 713:CO:SNTL  18.8        in       49.0
#
#                                       SNOWDEPTH_units datasource     DENSITY
# datetime                  site
# 2021-04-29 08:00:00+00:00 713:CO:SNTL              in       NRCS  376.000000
# 2021-04-30 08:00:00+00:00 713:CO:SNTL              in       NRCS  383.673469

# %%
red_mountain_location = red_mountain_site.metadata

print(f"Red Mountain Location = {red_mountain_site.metadata}")
red_mountain_lat = red_mountain_location.y
red_mountain_lon = red_mountain_location.x
red_mountain_elevation = red_mountain_location.z
# Out:
# Red Mountain Location = POINT Z (-107.71389 37.89168 11080)

# %%
df_swe.to_csv('Red_Mountain_station')

# %%
site_location = site.metadata
print(f"{site.name} location is {site_location}")
site_lat = site_location.y
site_lon = site_location.x
site_elevation = site_location.z
# Out:
# Senator Beck Study Plot location is POINT Z (-107.72627 37.90688 12186)

# %% [markdown]
# Store georeference data

# %%
df_rad.to_file("radiationdata.geojson")

# %%
import geopandas as gpd
df = gpd.read_file('radiationdata.geojson')

# %%
df
# Out:
#               datetime  site UPWARD BROADBAND RADIATION  \
# 0  2021-04-29 00:00:00  SBSP                     -3.093
# 1  2021-04-29 01:00:00  SBSP                     -3.365
# 2  2021-04-29 02:00:00  SBSP                      -3.34
# 3  2021-04-29 03:00:00  SBSP                     -3.367
# 4  2021-04-29 04:00:00  SBSP                     -3.546
# 5  2021-04-29 05:00:00  SBSP                     -3.795
# 6  2021-04-29 06:00:00  SBSP                      34.78
# 7  2021-04-29 07:00:00  SBSP                      237.1
# 8  2021-04-29 08:00:00  SBSP                      476.4
# 9  2021-04-29 09:00:00  SBSP                      697.2
# 10 2021-04-29 10:00:00  SBSP                        884
# 11 2021-04-29 11:00:00  SBSP                       1018
# 12 2021-04-29 12:00:00  SBSP                       1084
# 13 2021-04-29 13:00:00  SBSP                       1092
# 14 2021-04-29 14:00:00  SBSP                       1035
# 15 2021-04-29 15:00:00  SBSP                        914
# 16 2021-04-29 16:00:00  SBSP                        740
# 17 2021-04-29 17:00:00  SBSP                      521.7
# 18 2021-04-29 18:00:00  SBSP                      257.1
# 19 2021-04-29 19:00:00  SBSP                      13.42
# 20 2021-04-29 20:00:00  SBSP                     -3.283
# 21 2021-04-29 21:00:00  SBSP                      -3.44
# 22 2021-04-29 22:00:00  SBSP                     -3.753
# 23 2021-04-29 23:00:00  SBSP                     -3.405
# 24 2021-04-30 00:00:00  SBSP                       None
#
#    UPWARD NIR/SWIR RADIATION DOWNWARD BROADBAND RADIATION  \
# 0                     -3.393                        0.325
# 1                     -3.696                        0.315
# 2                     -3.737                        0.276
# 3                     -3.632                        0.264
# 4                     -3.855                        0.249
# 5                     -4.144                        0.267
# 6                      12.75                        47.84
# 7                      106.3                        239.7
# 8                      260.6                        425.4
# 9                      359.9                          584
# 10                     449.8                          710
# 11                     523.1                          783
# 12                     578.4                          789
# 13                     597.9                          755
# 14                     564.2                        686.6
# 15                       493                        591.1
# 16                     398.4                        466.4
# 17                       282                        316.7
# 18                     138.9                        142.1
# 19                    -0.095                        15.14
# 20                    -3.661                        0.631
# 21                      -3.6                        0.047
# 22                     -3.97                        0.106
# 23                    -3.569                        0.017
# 24                      None                         None
#
#    DOWNWARD NIR/SWIR RADIATION SNOWDEPTH UPWARD BROADBAND RADIATION_units  \
# 0                        0.269     1.242                            w/m^2
# 1                        0.294     1.239                            w/m^2
# 2                        0.163     1.242                            w/m^2
# 3                         0.12     1.232                            w/m^2
# 4                         0.04     1.231                            w/m^2
# 5          0.07099999999999999     1.232                            w/m^2
# 6                        27.12     1.224                            w/m^2
# 7                        119.7     1.212                            w/m^2
# 8                        199.5     1.213                            w/m^2
# 9                        266.3      1.22                            w/m^2
# 10                       317.2     1.212                            w/m^2
# 11                       341.6     1.215                            w/m^2
# 12                       333.7     1.186                            w/m^2
# 13                       308.6     1.193                            w/m^2
# 14                       278.6      1.18                            w/m^2
# 15                       240.4     1.179                            w/m^2
# 16                       190.6     1.185                            w/m^2
# 17                       131.5     1.185                            w/m^2
# 18                       57.62     1.182                            w/m^2
# 19                       2.891     1.184                            w/m^2
# 20                       0.279     1.185                            w/m^2
# 21                       0.002     1.182                            w/m^2
# 22                       0.016     1.181                            w/m^2
# 23                      -0.056     1.179                            w/m^2
# 24                        None      None                            w/m^2
#
#    UPWARD NIR/SWIR RADIATION_units DOWNWARD BROADBAND RADIATION_units  \
# 0                            w/m^2                              w/m^2
# 1                            w/m^2                              w/m^2
# 2                            w/m^2                              w/m^2
# 3                            w/m^2                              w/m^2
# 4                            w/m^2                              w/m^2
# 5                            w/m^2                              w/m^2
# 6                            w/m^2                              w/m^2
# 7                            w/m^2                              w/m^2
# 8                            w/m^2                              w/m^2
# 9                            w/m^2                              w/m^2
# 10                           w/m^2                              w/m^2
# 11                           w/m^2                              w/m^2
# 12                           w/m^2                              w/m^2
# 13                           w/m^2                              w/m^2
# 14                           w/m^2                              w/m^2
# 15                           w/m^2                              w/m^2
# 16                           w/m^2                              w/m^2
# 17                           w/m^2                              w/m^2
# 18                           w/m^2                              w/m^2
# 19                           w/m^2                              w/m^2
# 20                           w/m^2                              w/m^2
# 21                           w/m^2                              w/m^2
# 22                           w/m^2                              w/m^2
# 23                           w/m^2                              w/m^2
# 24                           w/m^2                              w/m^2
#
#    DOWNWARD NIR/SWIR RADIATION_units SNOWDEPTH_units datasource  \
# 0                              w/m^2          meters       CSAS
# 1                              w/m^2          meters       CSAS
# 2                              w/m^2          meters       CSAS
# 3                              w/m^2          meters       CSAS
# 4                              w/m^2          meters       CSAS
# 5                              w/m^2          meters       CSAS
# 6                              w/m^2          meters       CSAS
# 7                              w/m^2          meters       CSAS
# 8                              w/m^2          meters       CSAS
# 9                              w/m^2          meters       CSAS
# 10                             w/m^2          meters       CSAS
# 11                             w/m^2          meters       CSAS
# 12                             w/m^2          meters       CSAS
# 13                             w/m^2          meters       CSAS
# 14                             w/m^2          meters       CSAS
# 15                             w/m^2          meters       CSAS
# 16                             w/m^2          meters       CSAS
# 17                             w/m^2          meters       CSAS
# 18                             w/m^2          meters       CSAS
# 19                             w/m^2          meters       CSAS
# 20                             w/m^2          meters       CSAS
# 21                             w/m^2          meters       CSAS
# 22                             w/m^2          meters       CSAS
# 23                             w/m^2          meters       CSAS
# 24                             w/m^2          meters       CSAS
#
#                                      geometry
# 0   POINT Z (-107.72627 37.90688 12186.00000)
# 1   POINT Z (-107.72627 37.90688 12186.00000)
# 2   POINT Z (-107.72627 37.90688 12186.00000)
# 3   POINT Z (-107.72627 37.90688 12186.00000)
# 4   POINT Z (-107.72627 37.90688 12186.00000)
# 5   POINT Z (-107.72627 37.90688 12186.00000)
# 6   POINT Z (-107.72627 37.90688 12186.00000)
# 7   POINT Z (-107.72627 37.90688 12186.00000)
# 8   POINT Z (-107.72627 37.90688 12186.00000)
# 9   POINT Z (-107.72627 37.90688 12186.00000)
# 10  POINT Z (-107.72627 37.90688 12186.00000)
# 11  POINT Z (-107.72627 37.90688 12186.00000)
# 12  POINT Z (-107.72627 37.90688 12186.00000)
# 13  POINT Z (-107.72627 37.90688 12186.00000)
# 14  POINT Z (-107.72627 37.90688 12186.00000)
# 15  POINT Z (-107.72627 37.90688 12186.00000)
# 16  POINT Z (-107.72627 37.90688 12186.00000)
# 17  POINT Z (-107.72627 37.90688 12186.00000)
# 18  POINT Z (-107.72627 37.90688 12186.00000)
# 19  POINT Z (-107.72627 37.90688 12186.00000)
# 20  POINT Z (-107.72627 37.90688 12186.00000)
# 21  POINT Z (-107.72627 37.90688 12186.00000)
# 22  POINT Z (-107.72627 37.90688 12186.00000)
# 23  POINT Z (-107.72627 37.90688 12186.00000)
# 24  POINT Z (-107.72627 37.90688 12186.00000)

# %%
df.to_csv('Senator_beck_basin_station')
